# %% [markdown]
# <a href="https://colab.research.google.com/github/mshilpaa/ethereum-data-analysis/blob/master/Final/Modify_labels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np

# %%
 data_with_labels = pd.read_csv('/content/gdrive/My Drive/project_data/Final/data_with_labels.csv')

# %%
data_with_labels
# Out:
#      Unnamed: 0  ... labels
# 0           457  ...      1
# 1            12  ...      0
# 2            25  ...      0
# 3            99  ...      0
# 4           102  ...      0
# ..          ...  ...    ...
# 123         111  ...      6
# 124         166  ...      6
# 125         257  ...      6
# 126         368  ...      6
# 127         433  ...      6
#
# [128 rows x 20 columns]

# %%
zero = data_with_labels[data_with_labels['labels'] == 0]
# category = [ "Advertising",
#      "Basic-Attention-Token",,
#             "CoinMarketFeed",
#             "CoinMarketFeed",
#                "CryptoAtoms",
#                "Derivatives",
#                     "DutchX",
#                 "Hot-Wallet",
#                       "Nexo",
#                      "Nexo",
#                    "Orchid",
#           "Origin-Protocol",
#                     "Remme",
#                   "Sablier","
#            "Scroll-Network"]
zero['Category'].at[7] ="CoinMarketFeed"
zero['Category'].at[14] ="CoinMarketFeed"
zero['Category'].at[10] ="CoinMarketFeed"
zero['Category'].at[1] ="CoinMarketFeed"
#CoinMarketFeed

# %%
zero
# Out:
#     Unnamed: 0  ... labels
# 1           12  ...      0
# 2           25  ...      0
# 3           99  ...      0
# 4          102  ...      0
# 5          129  ...      0
# 6          180  ...      0
# 7          200  ...      0
# 8          253  ...      0
# 9          337  ...      0
# 10         338  ...      0
# 11         356  ...      0
# 12         363  ...      0
# 13         399  ...      0
# 14         416  ...      0
# 15         424  ...      0
#
# [15 rows x 20 columns]

# %%
one = data_with_labels[data_with_labels['labels'] == 1]
print(one.shape)
one["Category"]

#Syscoin
# Out:
# (1, 20)
# 0    Syscoin
# Name: Category, dtype: object

# %%
two = data_with_labels[data_with_labels['labels'] == 2]
print(two.shape)
two["Category"]
#Charity
# Out:
# (1, 20)
# 16    Charity
# Name: Category, dtype: object

# %%
three = data_with_labels[data_with_labels['labels'] == 3]
print(three.shape)
three["Category"]
three['Category'].at[20] ="Coinone"
three['Category'].at[24] ="Coinone"
# Coinone
# Out:
# (8, 20)

# %%
four = data_with_labels[data_with_labels['labels'] == 4]
print(four.shape)
four["Category"]
four['Category'].at[25] ="MESG"
four['Category'].at[31] ="MESG"
four['Category'].at[35] ="MESG"
four['Category'].at[34] ="MESG"
four['Category'].at[25] ="MESG"
four['Category']
# MESG
# Out:
# (12, 20)
# 25           MESG
# 26         Kraken
# 27         Liquid
# 28           MESG
# 29           MESG
# 30           MESG
# 31           MESG
# 32    POA-Network
# 33       Resfinex
# 34           MESG
# 35           MESG
# 36       Swipe-io
# Name: Category, dtype: object

# %%
five = data_with_labels[data_with_labels['labels'] == 5]
print(five.shape)
five["Category"][five["Category"]=="BitMart"]
five['Category'].at[37] ="Wallet-App"
five['Category'].at[41] ="Wallet-App"
five['Category'].at[38] ="Wallet-App"
five['Category'].at[39] ="Wallet-App"
five['Category'].at[41] ="Wallet-App"
five['Category'].at[53] ="Wallet-App"
five['Category'].at[57] ="Wallet-App"
five['Category'].at[116] ="Wallet-App"
five['Category'].at[34] ="Wallet-App"
five['Category'].at[117] ="Wallet-App"
five['Category'].at[118] ="Wallet-App"
five['Category'].at[99] ="Wallet-App"
five['Category'].at[88] ="Wallet-App"
five['Category'].at[77] ="Wallet-App"
five['Category'].at[56] ="Wallet-App"
five['Category'].at[63] ="Wallet-App"
five['Category'].at[71] ="Wallet-App"
five['Category'].at[69] ="Wallet-App"
five['Category'].at[99] ="Wallet-App"
five['Category'].at[111] ="Wallet-App"
five["Category"][five["Category"]=="Wallet-App"].count()
#Wallet-App
# Out:
# (84, 20)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# 21

# %%
six = data_with_labels[data_with_labels['labels'] == 6]
print(six.shape)
six["Category"]
six['Category'].at[121] ="Cold-Wallet"
six['Category'].at[122] ="Cold-Wallet"
six['Category'].at[127] ="Cold-Wallet"
six['Category']
#Cold Wallet
# Out:
# (7, 20)
# 121    Cold-Wallet
# 122    Cold-Wallet
# 123    Cold-Wallet
# 124       Curve-fi
# 125       Humanity
# 126          Origo
# 127    Cold-Wallet
# Name: Category, dtype: object

# %%
frames = [zero,one,two,three,four,five,six]
result = pd.concat(frames)

# %%
result.to_csv(r'/content/gdrive/My Drive/project_data/Final/modified_labels.csv', index = True)
